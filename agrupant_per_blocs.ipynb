# %%
import numpy as np
import pandas as pd
import copy
from scipy.optimize import nnls, minimize

df = pd.read_csv("data.csv", index_col=0)
df
# Out:
#            PSC     JUNTS       ERC        PP       VOX    COMUNS       CUP  \
# 1980  0.138185  0.171275  0.054873  0.014556  0.000000  0.115557  0.000000
# 1984  0.193811  0.301318  0.028411  0.049647  0.000000  0.035962  0.000000
# 1988  0.177197  0.272179  0.024616  0.031648  0.000000  0.046166  0.000000
# 1992  0.152089  0.255296  0.043962  0.032968  0.000000  0.035913  0.000000
# 1995  0.159822  0.263467  0.061096  0.084246  0.000000  0.062607  0.000000
# 1999  0.227821  0.226843  0.052261  0.057211  0.000000  0.015129  0.000000
# 2003  0.198586  0.196993  0.104874  0.075627  0.000000  0.046480  0.000000
# 2006  0.153722  0.180767  0.080571  0.060980  0.000000  0.054760  0.000000
# 2010  0.111491  0.234199  0.042640  0.075148  0.000000  0.044927  0.000000
# 2012  0.101217  0.215104  0.095984  0.091014  0.000000  0.069380  0.024398
# 2015  0.095612  0.177772  0.119819  0.063803  0.000000  0.067168  0.061720
# 2017  0.109923  0.171815  0.169573  0.033642  0.000000  0.059135  0.035377
# 2021  0.117794  0.102642  0.108946  0.019691  0.039241  0.035143  0.034168
# 2024  0.155049  0.119717  0.075739  0.060989  0.044111  0.032376  0.022672
#
#       ALIANÇA.CAT    Altres        Cs  Abstenció
# 1980     0.000000  0.117144  0.000000   0.388410
# 1984     0.000000  0.031802  0.000000   0.359048
# 1988     0.000000  0.039541  0.000000   0.408652
# 1992     0.000000  0.025621  0.000000   0.454152
# 1995     0.000000  0.005756  0.000000   0.363006
# 1999     0.000000  0.016845  0.000000   0.403890
# 2003     0.000000  0.008517  0.000000   0.368922
# 2006     0.000000  0.013357  0.017425   0.438418
# 2010     0.000000  0.061473  0.020696   0.409426
# 2012     0.000000  0.040548  0.053099   0.309256
# 2015     0.000000  0.027295  0.134545   0.252267
# 2017     0.000000  0.008989  0.201077   0.210469
# 2021     0.000000  0.021047  0.028534   0.492794
# 2024     0.020932  0.016609  0.000000   0.451805

# %%
df["Dreta espanyola"] = df["PP"] + df["Cs"] + df["VOX"]
df["Dreta catalana"] = df["JUNTS"] + df["ALIANÇA.CAT"]
df["Esquerra catalana"] = df["ERC"] + df["CUP"]
df["Esquerra espanyola"] = df["PSC"] + df["COMUNS"]
df.drop(columns=["PP", "Cs", "VOX", "JUNTS", "ALIANÇA.CAT", "ERC", "CUP", "PSC", "COMUNS"], inplace=True)
df
# Out:
#         Altres  Abstenció  Dreta espanyola  Dreta catalana  Esquerra catalana  \
# 1980  0.117144   0.388410         0.014556        0.171275           0.054873
# 1984  0.031802   0.359048         0.049647        0.301318           0.028411
# 1988  0.039541   0.408652         0.031648        0.272179           0.024616
# 1992  0.025621   0.454152         0.032968        0.255296           0.043962
# 1995  0.005756   0.363006         0.084246        0.263467           0.061096
# 1999  0.016845   0.403890         0.057211        0.226843           0.052261
# 2003  0.008517   0.368922         0.075627        0.196993           0.104874
# 2006  0.013357   0.438418         0.078405        0.180767           0.080571
# 2010  0.061473   0.409426         0.095844        0.234199           0.042640
# 2012  0.040548   0.309256         0.144113        0.215104           0.120382
# 2015  0.027295   0.252267         0.198348        0.177772           0.181539
# 2017  0.008989   0.210469         0.234719        0.171815           0.204950
# 2021  0.021047   0.492794         0.087466        0.102642           0.143114
# 2024  0.016609   0.451805         0.105100        0.140649           0.098411
#
#       Esquerra espanyola
# 1980            0.253742
# 1984            0.229773
# 1988            0.223363
# 1992            0.188002
# 1995            0.222429
# 1999            0.242950
# 2003            0.245066
# 2006            0.208482
# 2010            0.156418
# 2012            0.170597
# 2015            0.162780
# 2017            0.169058
# 2021            0.152937
# 2024            0.187425

# %%
list(df.columns)
# Out:
# ['Altres',
#  'Abstenció',
#  'Dreta espanyola',
#  'Dreta catalana',
#  'Esquerra catalana',
#  'Esquerra espanyola']

# %%
from utils import StableMarkovChain

mc = StableMarkovChain(df)
mc.fit(decay_rate=0.3,sparse_threshold=1e-9,fidelitat_threshold=0.001)

print(mc)
mc.plot_transition_matrix()
# Out:
# Model ajustat correctament amb pesos temporals (Decay Rate: 0.3)
# Model de Cadena de Markov Estable (14 Anys, 6 Partits)
# =======================================================
# Matriu de Transició Global (Files = Destí, Columnes = Origen):
#                     Altres  Abstenció  Dreta espanyola  Dreta catalana  Esquerra catalana  Esquerra espanyola
# Altres              0.8391     0.0000           0.0007          0.0002             0.0020              0.0023
# Abstenció           0.0000     0.5890           0.4735          0.0000             0.4687              0.2560
# Dreta espanyola     0.0982     0.1027           0.4117          0.1732             0.0211              0.0000
# Dreta catalana      0.0017     0.1902           0.0000          0.5371             0.0000              0.0297
# Esquerra catalana   0.0609     0.0000           0.1095          0.2676             0.4761              0.0000
# Esquerra espanyola  0.0000     0.1181           0.0046          0.0218             0.0321              0.7120

# %%
print(mc.get_steady_state())
mc.plot_steady_state()
# Out:
# La matriu és irreductible. Calculant distribució estacionària amb valors propis...
# Altres                0.004837
# Abstenció             0.392727
# Dreta espanyola       0.124624
# Dreta catalana        0.173520
# Esquerra catalana     0.115242
# Esquerra espanyola    0.189050
# dtype: float64

# %%
"""import numpy as np

eigenvalues, eigenvectors = np.linalg.eig(df_P_final)

# Trobar l'índex de l'autovalor més proper a 1
idx = np.argmin(np.abs(eigenvalues - 1))

# Extreure el vector i normalitzar (suma = 1)
pi = np.real(eigenvectors[:, idx])
pi = pi / pi.sum()

partits = list(df_P_final.columns)
for p, v in zip(partits, pi):
    print(f"{p:10s}: {v:.4f}")

###### COMPROVACIÓ DE LA DISTRIBUCIÓ ESTACIONÀRIA ######
print("\nComprovació de la distribució estacionària:")
print(np.allclose(df_P_final @ pi, pi))  # Ha de donar True
print(pi.sum())                    # Ha de donar 1.0"""
# Out:
# 'import numpy as np\n\neigenvalues, eigenvectors = np.linalg.eig(df_P_final)\n\n# Trobar l\'índex de l\'autovalor més proper a 1\nidx = np.argmin(np.abs(eigenvalues - 1))\n\n# Extreure el vector i normalitzar (suma = 1)\npi = np.real(eigenvectors[:, idx])\npi = pi / pi.sum()\n\npartits = list(df_P_final.columns)\nfor p, v in zip(partits, pi):\n    print(f"{p:10s}: {v:.4f}")\n\n###### COMPROVACIÓ DE LA DISTRIBUCIÓ ESTACIONÀRIA ######\nprint("\nComprovació de la distribució estacionària:")\nprint(np.allclose(df_P_final @ pi, pi))  # Ha de donar True\nprint(pi.sum())                    # Ha de donar 1.0'

# %% [markdown]
# Per al Teorema de Perron-Frobenius, una cadena de Markov irreductible i aperiòdica sempre té una única distribució estacionària π > 0.

# %%
mc.verify_steady_state()
# Out:
# VERIFICACIÓ DE L'EXISTÈNCIA DE LA DISTR. ESTACIONÀRIA
#
# 1. Matriu estocàstica (columnes sumen 1):
#    · Sumes de cada columna: [1. 1. 1. 1. 1. 1.]
#    · Columnes sumen 1:      True
#    · Valors no negatius:    True
#
# 2. Irreductibilitat (tots els estats es comuniquen): True
#
# 3. Aperiodicitat (self-loops a la diagonal): True
#    → La cadena és APERIÒDICA
#
# EXISTEIX distribució estacionària ÚNICA
# True

# %%
mc.export_for_flourish("election_flows_agrupant_per_blocs.csv")
mc.plot_chord()
# Out:
# [OK] Flourish file saved: election_flows_agrupant_per_blocs.csv

# %%
mc.plot_graph()

# %% [markdown]
# ### Efecte d'una campanya
# Per fer-ho canviem un valor de la matriu de transició, augmentant el nombre de votants que es queden del partit politic que fa la campanya.

# %%
col = "Dreta espanyola"
mc2 = copy.deepcopy(mc)
mc2.transition_matrix.loc[col, col] = 0.6

# Renormalitzem la fila
mc2.transition_matrix[col] /= mc2.transition_matrix[col].sum()

# Verifiquem que segueix sumant 1
print(mc2.transition_matrix[col].sum())
# Out:
# 1.0

# %%
print(mc2.get_steady_state())
mc2.plot_steady_state()
# Out:
# La matriu és irreductible. Calculant distribució estacionària amb valors propis...
# Altres                0.004726
# Abstenció             0.383722
# Dreta espanyola       0.144696
# Dreta catalana        0.169542
# Esquerra catalana     0.112599
# Esquerra espanyola    0.184715
# dtype: float64

# %% [markdown]
# ### Temps per arribar a solució estacionària

# %% [markdown]
# Fem una simulació de l'evolució de la matriu de transició a partir de l'estat incial (any 1980). Amb aquesta simulació veiem en quantes eleccions arriba a la solució estàcionaria que haviem calculat anteriorment i fem una aproximació per calcular els anys total (num_eleccions * 4)

# %%
pi = mc.get_steady_state().values
p0 = df.loc[1980].values
epsilon = 1e-5
p = p0.copy()
t = 0
historia = [p.copy()]

P = mc.transition_matrix.values

# Afegeix un màxim de passos per seguretat
MAX_PASSOS = 10000

while t < MAX_PASSOS:
    p_nou = P @ p
    diferencia = np.max(np.abs(p_nou - pi))
    historia.append(p_nou.copy())
    t += 1
    if diferencia < epsilon:
        break
    p = p_nou

if t == MAX_PASSOS:
    print("No ha convergit en el màxim de passos!")

print(f"Convergència assolida en {t} eleccions (~{t*4} anys)")
print(f"Distribució estacionària π:")
for partit, prob in zip(list(df.columns), pi):
    print(f"  {partit}: {prob:.3f}")
# Out:
# La matriu és irreductible. Calculant distribució estacionària amb valors propis...
# Convergència assolida en 53 eleccions (~212 anys)
# Distribució estacionària π:
#   Altres: 0.005
#   Abstenció: 0.393
#   Dreta espanyola: 0.125
#   Dreta catalana: 0.174
#   Esquerra catalana: 0.115
#   Esquerra espanyola: 0.189

# %%
import matplotlib.pyplot as plt

historia = np.array(historia)

plt.figure(figsize=(12, 5))
for j, partit in enumerate(list(df.columns)):
    plt.plot(historia[:, j], label=partit)
plt.axhline(y=0, color='k', linewidth=0.5)
plt.xlabel("Eleccions")
plt.ylabel("Quota de vot")
plt.title("Convergència cap a la distribució estacionària")
plt.legend()
plt.show()

# %% [markdown]
# ### Costumer lifetime value

# %% [markdown]
# Busquem el número d'eleccions consecutives que de mitjana un votant votaria al mateix partit: $\frac{1}{1-retenció}$

# %%
retencio = mc.transition_matrix.values.diagonal()
print("Retenció (probabilitat de mantenir votants):")

clv = 1 / (1 - retencio)

print("CLV (Customer Lifetime Value) estimat per cada partit:")
for partit, clv_value in zip(list(df.columns), clv):
    print(f"  {partit}: {round(clv_value, 2)} ~ {round(clv_value, 0)} eleccions")
# Out:
# Retenció (probabilitat de mantenir votants):
# CLV (Customer Lifetime Value) estimat per cada partit:
#   Altres: 6.22 ~ 6.0 eleccions
#   Abstenció: 2.43 ~ 2.0 eleccions
#   Dreta espanyola: 1.7 ~ 2.0 eleccions
#   Dreta catalana: 2.16 ~ 2.0 eleccions
#   Esquerra catalana: 1.91 ~ 2.0 eleccions
#   Esquerra espanyola: 3.47 ~ 3.0 eleccions
